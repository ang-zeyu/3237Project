# %%
# Import data related libraries
import pandas as pd
import numpy as np
import random
import json

# Import label encoder
from sklearn.preprocessing import LabelEncoder

# Import train test split
from sklearn.model_selection import train_test_split

# Import neural network libraries
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD

# %%
# Set up GPU
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Load and clean data

# %%
# Replace double quotes with single quotes for moods JSON arrays
f = open('song_data.csv','r+')
text = f.read()
text = text.replace('"["', '"[?').replace('", "', '?,?').replace('"]"', '?]"') # Changed to "[$Happy$,$Sad$]" for easy replacing later
f.seek(0)
f.write(text)
f.close()

# %%
# Importing data
df = pd.read_csv('song_data.csv', index_col=0)
for col in df.columns:
    # drops motion data and uuid
    if col == 'uuid' or 'gyro' in col or 'accel' in col:
        df.drop(col, axis=1, inplace=True)
df.dropna(inplace=True) # drop rows with nan values
df.size
# Out:
# 2395

# %%
# Format contents of columns properly
for col in df.columns:
  if col not in ['id','isSkipped']:
    if col == 'moods':
      df[col] = df[col].apply(lambda x:str(x).replace('?','"'))
    df[col] = df[col].apply(lambda x:json.loads(x))

# Add random activity to rows
df['activity'] = df.apply(lambda _: random.choice(['Running','Walking','Working']), axis=1) # initialise random activity
df.head()
# Out:
#                                               optical  ... activity
# id                                                     ...
# 1                    [139.64, 138.36, 139.64, 140.28]  ...  Walking
# 2                    [123.24, 123.24, 139.32, 228.64]  ...  Walking
# 3   [256.08, 307.84000000000003, 315.2, 301.36, 30...  ...  Walking
# 4                    [127.08, 126.76, 125.48, 124.52]  ...  Walking
# 5                      [145.76, 144.48, 146.4, 144.8]  ...  Working
#
# [5 rows x 6 columns]

# %%
# Remove defective data
defective_ids = []
for id,row in df.iterrows():
    # defective if temp array only has -40 values
    # defective if any humidity values are above 99.99

    if len([k for k in row['temp'] if k == -40]) == len(row['temp']) or \
       len([k for k in row['humidity'] if k > 99.99]) == len(row['humidity']):
        defective_ids.append(id)
    
    # if only some values are defective, keep the row, but remove defective values
    # remove -40 temp values and >99.99 humidity values
    elif (-40 in row['temp']) or len([k for k in row['humidity'] if k>99.99]):
        row['temp'] = [k for k in row['temp'] if k!=-40]
        row['humidity'] = [k for k in row['humidity'] if k < 99.99]

filtered_df = df[~df.index.isin(defective_ids)].copy() # .copy() to avoid warning
print('Defective row ids are: ',defective_ids)
# Out:
# Defective row ids are:  ['21', '22', '33', '214', '236', '238', '245', '246', '247', '248', '249', '250', '251', '252', '386', '387', '388', '389', '390', '391', '392', '393', '394']

# %%
# Obtain mean optical, temp and humidity values
for col in df.columns:
    if col not in ['moods','isSkipped','activity']:
        filtered_df[col] = filtered_df[col].apply(np.mean)
filtered_df.head()
# Out:
#     optical       temp  ...  isSkipped activity
# id                      ...
# 1   139.480  30.505676  ...        0.0  Walking
# 2   153.610  31.694031  ...        0.0  Walking
# 3   297.792  32.217712  ...        0.0  Walking
# 4   125.960  32.429199  ...        1.0  Walking
# 5   145.360  32.429199  ...        1.0  Working
#
# [5 rows x 6 columns]

# %%
# Label encoding for activity
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
filtered_df['activity'] = labelencoder.fit_transform(filtered_df['activity'])
filtered_df.head()
# Out:
#     optical       temp  ...  isSkipped activity
# id                      ...
# 1   139.480  30.505676  ...        0.0        1
# 2   153.610  31.694031  ...        0.0        1
# 3   297.792  32.217712  ...        0.0        1
# 4   125.960  32.429199  ...        1.0        1
# 5   145.360  32.429199  ...        1.0        2
#
# [5 rows x 6 columns]

# %%
# One-hot encoding for moods
moods = []
for k in filtered_df['moods'].values:
    moods += list(k)
moods = np.unique(np.array(moods))
for mood in moods:
    mood_values = filtered_df['moods'].astype(str).str.contains(mood)
    filtered_df[mood] = mood_values
filtered_df.drop('moods', axis=1, inplace=True)
print('Added one-hot encoded columns for moods:')
filtered_df.head()
# Out:
# Added one-hot encoded columns for moods:
#     optical       temp   humidity  ...  Elegant  Passionate   Warm
# id                                 ...
# 1   139.480  30.505676  71.313477  ...    False       False  False
# 2   153.610  31.694031  67.053223  ...    False       False  False
# 3   297.792  32.217712  65.850830  ...    False        True  False
# 4   125.960  32.429199  64.672852  ...     True       False  False
# 5   145.360  32.429199  64.672852  ...    False        True  False
#
# [5 rows x 13 columns]

# %%
# Invert mood boolean values based on "isSkipped"
for mood in moods:
    filtered_df[mood] = np.abs(filtered_df[mood] - filtered_df['isSkipped'])
filtered_df.drop('isSkipped', axis=1, inplace=True)
print('Invert mood values based on "isSkipped" boolean:')
filtered_df.head()
# Out:
# Invert mood values based on "isSkipped" boolean:
#     optical       temp   humidity  ...  Elegant  Passionate  Warm
# id                                 ...
# 1   139.480  30.505676  71.313477  ...      0.0         0.0   0.0
# 2   153.610  31.694031  67.053223  ...      0.0         0.0   0.0
# 3   297.792  32.217712  65.850830  ...      0.0         1.0   0.0
# 4   125.960  32.429199  64.672852  ...      0.0         1.0   1.0
# 5   145.360  32.429199  64.672852  ...      1.0         0.0   1.0
#
# [5 rows x 12 columns]

# %% [markdown]
# # MLP Classifier
# * Normalize input data before training, to control loss

# %%
# Split train and test
X = filtered_df[['optical', 'temp', 'humidity', 'activity']]
Y = filtered_df[['Aggressive', 'Athletic', 'Atmospheric', 'Celebratory', \
                 'Depressive', 'Elegant', 'Passionate', 'Warm']]

# Normalize input data using MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# fit scaler on data
scaler.fit(X)

# apply transform
X = scaler.transform(X)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state = 0, test_size = 0.2)

# %%
# MLP model training
model = Sequential()

# Input layer
model.add(Dense(8, input_dim=4, activation='relu'))

model.add(Dropout(0.3))

# Hidden layer
model.add(Dense(8, activation='relu'))

# Output layer
model.add(Dense(8, activation='softmax'))

# Create a Stochastic Gradient Descent optimizer
sgd  = SGD(learning_rate = 0.0001, decay = 1e-4, momentum = 0.9)

# Compile the model.
model.compile(loss = 'categorical_crossentropy', optimizer = sgd,
             metrics = 'accuracy')

model.fit(x = X_train, y = Y_train, shuffle = True, batch_size = 60, 
          epochs = 150, validation_data = (X_test, Y_test))
# Out:
# Epoch 1/150
# 7/7 [==============================] - 1s 38ms/step - loss: 7.9297 - accuracy: 0.3049 - val_loss: 7.3425 - val_accuracy: 0.3913
# Epoch 2/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9463 - accuracy: 0.3242 - val_loss: 7.3414 - val_accuracy: 0.3913
# Epoch 3/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9385 - accuracy: 0.3407 - val_loss: 7.3399 - val_accuracy: 0.3913
# Epoch 4/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9167 - accuracy: 0.3297 - val_loss: 7.3384 - val_accuracy: 0.4130
# Epoch 5/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9264 - accuracy: 0.3214 - val_loss: 7.3369 - val_accuracy: 0.4130
# Epoch 6/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9313 - accuracy: 0.3187 - val_loss: 7.3354 - val_accuracy: 0.4130
# Epoch 7/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9208 - accuracy: 0.3187 - val_loss: 7.3341 - val_accuracy: 0.4130
# Epoch 8/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9188 - accuracy: 0.3242 - val_loss: 7.3328 - val_accuracy: 0.4130
# Epoch 9/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9070 - accuracy: 0.2885 - val_loss: 7.3315 - val_accuracy: 0.4130
# Epoch 10/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9146 - accuracy: 0.3269 - val_loss: 7.3303 - val_accuracy: 0.4022
# Epoch 11/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9216 - accuracy: 0.3049 - val_loss: 7.3293 - val_accuracy: 0.3913
# Epoch 12/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9154 - accuracy: 0.3049 - val_loss: 7.3283 - val_accuracy: 0.3696
# Epoch 13/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9245 - accuracy: 0.2885 - val_loss: 7.3274 - val_accuracy: 0.3152
# Epoch 14/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9108 - accuracy: 0.2940 - val_loss: 7.3264 - val_accuracy: 0.2283
# Epoch 15/150
# 7/7 [==============================] - 0s 9ms/step - loss: 7.9117 - accuracy: 0.2802 - val_loss: 7.3256 - val_accuracy: 0.1739
# Epoch 16/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9082 - accuracy: 0.2940 - val_loss: 7.3247 - val_accuracy: 0.1522
# Epoch 17/150
# 7/7 [==============================] - 0s 9ms/step - loss: 7.9148 - accuracy: 0.2445 - val_loss: 7.3241 - val_accuracy: 0.1196
# Epoch 18/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9213 - accuracy: 0.1978 - val_loss: 7.3234 - val_accuracy: 0.0978
# Epoch 19/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9144 - accuracy: 0.2308 - val_loss: 7.3228 - val_accuracy: 0.0870
# Epoch 20/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9123 - accuracy: 0.2033 - val_loss: 7.3224 - val_accuracy: 0.0978
# Epoch 21/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.8984 - accuracy: 0.1648 - val_loss: 7.3219 - val_accuracy: 0.1087
# Epoch 22/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9138 - accuracy: 0.1923 - val_loss: 7.3215 - val_accuracy: 0.0978
# Epoch 23/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9074 - accuracy: 0.2060 - val_loss: 7.3211 - val_accuracy: 0.0978
# Epoch 24/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.8960 - accuracy: 0.1731 - val_loss: 7.3209 - val_accuracy: 0.1196
# Epoch 25/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9028 - accuracy: 0.1868 - val_loss: 7.3206 - val_accuracy: 0.1196
# Epoch 26/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9024 - accuracy: 0.1621 - val_loss: 7.3204 - val_accuracy: 0.1196
# Epoch 27/150
# 7/7 [==============================] - 0s 9ms/step - loss: 7.8996 - accuracy: 0.1429 - val_loss: 7.3203 - val_accuracy: 0.1196
# Epoch 28/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9051 - accuracy: 0.1209 - val_loss: 7.3202 - val_accuracy: 0.1196
# Epoch 29/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9034 - accuracy: 0.1236 - val_loss: 7.3201 - val_accuracy: 0.1196
# Epoch 30/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9008 - accuracy: 0.1346 - val_loss: 7.3199 - val_accuracy: 0.1196
# Epoch 31/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.8975 - accuracy: 0.1181 - val_loss: 7.3198 - val_accuracy: 0.1196
# Epoch 32/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9179 - accuracy: 0.1016 - val_loss: 7.3197 - val_accuracy: 0.1196
# Epoch 33/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9050 - accuracy: 0.0962 - val_loss: 7.3198 - val_accuracy: 0.1196
# Epoch 34/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9040 - accuracy: 0.1071 - val_loss: 7.3198 - val_accuracy: 0.1196
# Epoch 35/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9046 - accuracy: 0.1154 - val_loss: 7.3199 - val_accuracy: 0.1196
# Epoch 36/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.8938 - accuracy: 0.1016 - val_loss: 7.3199 - val_accuracy: 0.1196
# Epoch 37/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.8918 - accuracy: 0.1044 - val_loss: 7.3200 - val_accuracy: 0.1196
# Epoch 38/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.8943 - accuracy: 0.1099 - val_loss: 7.3202 - val_accuracy: 0.1087
# Epoch 39/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9038 - accuracy: 0.1126 - val_loss: 7.3204 - val_accuracy: 0.1087
# Epoch 40/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.8928 - accuracy: 0.1071 - val_loss: 7.3207 - val_accuracy: 0.1087
# Epoch 41/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.8881 - accuracy: 0.0962 - val_loss: 7.3210 - val_accuracy: 0.1087
# Epoch 42/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9043 - accuracy: 0.0714 - val_loss: 7.3214 - val_accuracy: 0.1087
# Epoch 43/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.8986 - accuracy: 0.0962 - val_loss: 7.3218 - val_accuracy: 0.1087
# Epoch 44/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9035 - accuracy: 0.0797 - val_loss: 7.3222 - val_accuracy: 0.1087
# Epoch 45/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.8981 - accuracy: 0.0934 - val_loss: 7.3225 - val_accuracy: 0.1087
# Epoch 46/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.8847 - accuracy: 0.0824 - val_loss: 7.3228 - val_accuracy: 0.1087
# Epoch 47/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.8937 - accuracy: 0.0989 - val_loss: 7.3230 - val_accuracy: 0.1196
# Epoch 48/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.8984 - accuracy: 0.0824 - val_loss: 7.3233 - val_accuracy: 0.1196
# Epoch 49/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.8881 - accuracy: 0.1236 - val_loss: 7.3237 - val_accuracy: 0.1196
# Epoch 50/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9017 - accuracy: 0.0797 - val_loss: 7.3241 - val_accuracy: 0.1196
# Epoch 51/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.8988 - accuracy: 0.0962 - val_loss: 7.3246 - val_accuracy: 0.1196
# Epoch 52/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.8994 - accuracy: 0.1099 - val_loss: 7.3251 - val_accuracy: 0.1196
# Epoch 53/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9015 - accuracy: 0.0989 - val_loss: 7.3255 - val_accuracy: 0.1196
# Epoch 54/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.8883 - accuracy: 0.1044 - val_loss: 7.3259 - val_accuracy: 0.1196
# Epoch 55/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9017 - accuracy: 0.0852 - val_loss: 7.3263 - val_accuracy: 0.1196
# Epoch 56/150
# 7/7 [==============================] - 0s 10ms/step - loss: 7.9035 - accuracy: 0.0797 - val_loss: 7.3268 - val_accuracy: 0.1196
# Epoch 57/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9023 - accuracy: 0.1126 - val_loss: 7.3273 - val_accuracy: 0.1196
# Epoch 58/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.8922 - accuracy: 0.0879 - val_loss: 7.3279 - val_accuracy: 0.1196
# Epoch 59/150
# 7/7 [==============================] - 0s 10ms/step - loss: 7.9025 - accuracy: 0.0934 - val_loss: 7.3285 - val_accuracy: 0.1196
# Epoch 60/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9135 - accuracy: 0.0879 - val_loss: 7.3290 - val_accuracy: 0.1196
# Epoch 61/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9016 - accuracy: 0.0824 - val_loss: 7.3296 - val_accuracy: 0.1196
# Epoch 62/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.8915 - accuracy: 0.1044 - val_loss: 7.3302 - val_accuracy: 0.1196
# Epoch 63/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9027 - accuracy: 0.1071 - val_loss: 7.3310 - val_accuracy: 0.1196
# Epoch 64/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9036 - accuracy: 0.0962 - val_loss: 7.3317 - val_accuracy: 0.1087
# Epoch 65/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9052 - accuracy: 0.0989 - val_loss: 7.3324 - val_accuracy: 0.1087
# Epoch 66/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9053 - accuracy: 0.0879 - val_loss: 7.3330 - val_accuracy: 0.1087
# Epoch 67/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9006 - accuracy: 0.1099 - val_loss: 7.3337 - val_accuracy: 0.1087
# Epoch 68/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9134 - accuracy: 0.0907 - val_loss: 7.3343 - val_accuracy: 0.1087
# Epoch 69/150
# 7/7 [==============================] - 0s 9ms/step - loss: 7.9176 - accuracy: 0.1044 - val_loss: 7.3350 - val_accuracy: 0.1087
# Epoch 70/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9171 - accuracy: 0.0852 - val_loss: 7.3357 - val_accuracy: 0.1087
# Epoch 71/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9101 - accuracy: 0.0769 - val_loss: 7.3365 - val_accuracy: 0.1087
# Epoch 72/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9110 - accuracy: 0.0852 - val_loss: 7.3372 - val_accuracy: 0.1087
# Epoch 73/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9127 - accuracy: 0.0604 - val_loss: 7.3379 - val_accuracy: 0.1087
# Epoch 74/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9252 - accuracy: 0.0824 - val_loss: 7.3388 - val_accuracy: 0.1087
# Epoch 75/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9071 - accuracy: 0.0797 - val_loss: 7.3395 - val_accuracy: 0.0978
# Epoch 76/150
# 7/7 [==============================] - 0s 9ms/step - loss: 7.9156 - accuracy: 0.0907 - val_loss: 7.3403 - val_accuracy: 0.0978
# Epoch 77/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9207 - accuracy: 0.0742 - val_loss: 7.3412 - val_accuracy: 0.1087
# Epoch 78/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9061 - accuracy: 0.0742 - val_loss: 7.3420 - val_accuracy: 0.1087
# Epoch 79/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9118 - accuracy: 0.0632 - val_loss: 7.3427 - val_accuracy: 0.1087
# Epoch 80/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9114 - accuracy: 0.0989 - val_loss: 7.3435 - val_accuracy: 0.1087
# Epoch 81/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9203 - accuracy: 0.1044 - val_loss: 7.3445 - val_accuracy: 0.1087
# Epoch 82/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9113 - accuracy: 0.1044 - val_loss: 7.3455 - val_accuracy: 0.1087
# Epoch 83/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9277 - accuracy: 0.0824 - val_loss: 7.3464 - val_accuracy: 0.1087
# Epoch 84/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9207 - accuracy: 0.0604 - val_loss: 7.3473 - val_accuracy: 0.1087
# Epoch 85/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9169 - accuracy: 0.0852 - val_loss: 7.3481 - val_accuracy: 0.1196
# Epoch 86/150
# 7/7 [==============================] - 0s 10ms/step - loss: 7.9318 - accuracy: 0.0907 - val_loss: 7.3492 - val_accuracy: 0.1196
# Epoch 87/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9296 - accuracy: 0.0962 - val_loss: 7.3501 - val_accuracy: 0.1196
# Epoch 88/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9252 - accuracy: 0.0824 - val_loss: 7.3511 - val_accuracy: 0.1196
# Epoch 89/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9346 - accuracy: 0.0797 - val_loss: 7.3520 - val_accuracy: 0.1196
# Epoch 90/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9239 - accuracy: 0.1099 - val_loss: 7.3530 - val_accuracy: 0.1196
# Epoch 91/150
# 7/7 [==============================] - 0s 9ms/step - loss: 7.9110 - accuracy: 0.0989 - val_loss: 7.3541 - val_accuracy: 0.1196
# Epoch 92/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9226 - accuracy: 0.0824 - val_loss: 7.3552 - val_accuracy: 0.1196
# Epoch 93/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9281 - accuracy: 0.0769 - val_loss: 7.3563 - val_accuracy: 0.1196
# Epoch 94/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9279 - accuracy: 0.0824 - val_loss: 7.3574 - val_accuracy: 0.1196
# Epoch 95/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9351 - accuracy: 0.0714 - val_loss: 7.3587 - val_accuracy: 0.1196
# Epoch 96/150
# 7/7 [==============================] - 0s 9ms/step - loss: 7.9200 - accuracy: 0.0907 - val_loss: 7.3602 - val_accuracy: 0.1196
# Epoch 97/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9341 - accuracy: 0.0769 - val_loss: 7.3615 - val_accuracy: 0.1196
# Epoch 98/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9464 - accuracy: 0.1126 - val_loss: 7.3628 - val_accuracy: 0.1196
# Epoch 99/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9421 - accuracy: 0.0769 - val_loss: 7.3642 - val_accuracy: 0.1196
# Epoch 100/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9297 - accuracy: 0.0879 - val_loss: 7.3655 - val_accuracy: 0.1196
# Epoch 101/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9351 - accuracy: 0.0852 - val_loss: 7.3668 - val_accuracy: 0.1196
# Epoch 102/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9315 - accuracy: 0.1099 - val_loss: 7.3683 - val_accuracy: 0.1196
# Epoch 103/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9455 - accuracy: 0.0797 - val_loss: 7.3697 - val_accuracy: 0.1196
# Epoch 104/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9566 - accuracy: 0.0742 - val_loss: 7.3712 - val_accuracy: 0.1196
# Epoch 105/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9597 - accuracy: 0.0907 - val_loss: 7.3728 - val_accuracy: 0.1196
# Epoch 106/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9345 - accuracy: 0.0879 - val_loss: 7.3741 - val_accuracy: 0.1196
# Epoch 107/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9544 - accuracy: 0.0742 - val_loss: 7.3756 - val_accuracy: 0.1196
# Epoch 108/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9613 - accuracy: 0.0907 - val_loss: 7.3772 - val_accuracy: 0.1196
# Epoch 109/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9599 - accuracy: 0.0852 - val_loss: 7.3788 - val_accuracy: 0.1196
# Epoch 110/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9454 - accuracy: 0.0907 - val_loss: 7.3807 - val_accuracy: 0.1196
# Epoch 111/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9583 - accuracy: 0.0742 - val_loss: 7.3826 - val_accuracy: 0.1196
# Epoch 112/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9611 - accuracy: 0.0687 - val_loss: 7.3844 - val_accuracy: 0.1196
# Epoch 113/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9608 - accuracy: 0.0879 - val_loss: 7.3864 - val_accuracy: 0.1196
# Epoch 114/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9669 - accuracy: 0.0797 - val_loss: 7.3884 - val_accuracy: 0.1196
# Epoch 115/150
# 7/7 [==============================] - 0s 10ms/step - loss: 7.9649 - accuracy: 0.0714 - val_loss: 7.3902 - val_accuracy: 0.1196
# Epoch 116/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9627 - accuracy: 0.0742 - val_loss: 7.3922 - val_accuracy: 0.1196
# Epoch 117/150
# 7/7 [==============================] - 0s 9ms/step - loss: 7.9681 - accuracy: 0.0907 - val_loss: 7.3942 - val_accuracy: 0.1196
# Epoch 118/150
# 7/7 [==============================] - 0s 11ms/step - loss: 7.9866 - accuracy: 0.0879 - val_loss: 7.3964 - val_accuracy: 0.1087
# Epoch 119/150
# 7/7 [==============================] - 0s 9ms/step - loss: 7.9654 - accuracy: 0.0962 - val_loss: 7.3984 - val_accuracy: 0.1087
# Epoch 120/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9826 - accuracy: 0.0962 - val_loss: 7.4007 - val_accuracy: 0.1087
# Epoch 121/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9775 - accuracy: 0.0714 - val_loss: 7.4031 - val_accuracy: 0.1087
# Epoch 122/150
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9829 - accuracy: 0.0604 - val_loss: 7.4051 - val_accuracy: 0.1087
# Epoch 123/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9957 - accuracy: 0.0769 - val_loss: 7.4072 - val_accuracy: 0.1087
# Epoch 124/150
# 7/7 [==============================] - 0s 9ms/step - loss: 7.9973 - accuracy: 0.0879 - val_loss: 7.4096 - val_accuracy: 0.1087
# Epoch 125/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9820 - accuracy: 0.0769 - val_loss: 7.4127 - val_accuracy: 0.1087
# Epoch 126/150
# 7/7 [==============================] - 0s 8ms/step - loss: 8.0062 - accuracy: 0.0824 - val_loss: 7.4158 - val_accuracy: 0.1087
# Epoch 127/150
# 7/7 [==============================] - 0s 8ms/step - loss: 8.0049 - accuracy: 0.0907 - val_loss: 7.4184 - val_accuracy: 0.1087
# Epoch 128/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9960 - accuracy: 0.0852 - val_loss: 7.4211 - val_accuracy: 0.1087
# Epoch 129/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9965 - accuracy: 0.0714 - val_loss: 7.4238 - val_accuracy: 0.1087
# Epoch 130/150
# 7/7 [==============================] - 0s 9ms/step - loss: 7.9943 - accuracy: 0.0879 - val_loss: 7.4267 - val_accuracy: 0.1087
# Epoch 131/150
# 7/7 [==============================] - 0s 9ms/step - loss: 8.0025 - accuracy: 0.1044 - val_loss: 7.4294 - val_accuracy: 0.1087
# Epoch 132/150
# 7/7 [==============================] - 0s 8ms/step - loss: 7.9945 - accuracy: 0.1016 - val_loss: 7.4321 - val_accuracy: 0.1087
# Epoch 133/150
# 7/7 [==============================] - 0s 8ms/step - loss: 8.0169 - accuracy: 0.0879 - val_loss: 7.4351 - val_accuracy: 0.1087
# Epoch 134/150
# 7/7 [==============================] - 0s 9ms/step - loss: 8.0068 - accuracy: 0.0824 - val_loss: 7.4383 - val_accuracy: 0.1087
# Epoch 135/150
# 7/7 [==============================] - 0s 8ms/step - loss: 8.0261 - accuracy: 0.1044 - val_loss: 7.4414 - val_accuracy: 0.1087
# Epoch 136/150
# 7/7 [==============================] - 0s 8ms/step - loss: 8.0179 - accuracy: 0.0907 - val_loss: 7.4445 - val_accuracy: 0.1087
# Epoch 137/150
# 7/7 [==============================] - 0s 8ms/step - loss: 8.0515 - accuracy: 0.0879 - val_loss: 7.4477 - val_accuracy: 0.1087
# Epoch 138/150
# 7/7 [==============================] - 0s 7ms/step - loss: 8.0473 - accuracy: 0.1099 - val_loss: 7.4513 - val_accuracy: 0.1087
# Epoch 139/150
# 7/7 [==============================] - 0s 7ms/step - loss: 8.0410 - accuracy: 0.0907 - val_loss: 7.4547 - val_accuracy: 0.1087
# Epoch 140/150
# 7/7 [==============================] - 0s 7ms/step - loss: 8.0577 - accuracy: 0.0852 - val_loss: 7.4581 - val_accuracy: 0.1087
# Epoch 141/150
# 7/7 [==============================] - 0s 8ms/step - loss: 8.0453 - accuracy: 0.0907 - val_loss: 7.4618 - val_accuracy: 0.1087
# Epoch 142/150
# 7/7 [==============================] - 0s 7ms/step - loss: 8.0500 - accuracy: 0.0852 - val_loss: 7.4660 - val_accuracy: 0.1087
# Epoch 143/150
# 7/7 [==============================] - 0s 7ms/step - loss: 8.0538 - accuracy: 0.0989 - val_loss: 7.4700 - val_accuracy: 0.1087
# Epoch 144/150
# 7/7 [==============================] - 0s 7ms/step - loss: 8.0624 - accuracy: 0.0824 - val_loss: 7.4741 - val_accuracy: 0.1087
# Epoch 145/150
# 7/7 [==============================] - 0s 8ms/step - loss: 8.0489 - accuracy: 0.0962 - val_loss: 7.4781 - val_accuracy: 0.1087
# Epoch 146/150
# 7/7 [==============================] - 0s 7ms/step - loss: 8.0635 - accuracy: 0.0934 - val_loss: 7.4824 - val_accuracy: 0.1087
# Epoch 147/150
# 7/7 [==============================] - 0s 8ms/step - loss: 8.0719 - accuracy: 0.0879 - val_loss: 7.4865 - val_accuracy: 0.1087
# Epoch 148/150
# 7/7 [==============================] - 0s 8ms/step - loss: 8.0598 - accuracy: 0.0797 - val_loss: 7.4908 - val_accuracy: 0.1087
# Epoch 149/150
# 7/7 [==============================] - 0s 7ms/step - loss: 8.0690 - accuracy: 0.0989 - val_loss: 7.4948 - val_accuracy: 0.1087
# Epoch 150/150
# 7/7 [==============================] - 0s 7ms/step - loss: 8.0870 - accuracy: 0.1044 - val_loss: 7.4989 - val_accuracy: 0.1087
